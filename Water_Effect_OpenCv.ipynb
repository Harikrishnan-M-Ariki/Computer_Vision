# %%
import cv2
import matplotlib.pyplot as plt
import numpy

# %%
# %matplotlib inline

# %%
image=cv2.imread(r'/content/drive/MyDrive/Colab Notebooks/20220115_175044 (1).jpg')

# %%
plt.imshow(image[:,:,::-1])

# %%
image.shape
# Out:
# (1236, 3072, 3)

# %%
imgNew=numpy.zeros((image.shape[0]*2,image.shape[1],image.shape[2]),dtype=numpy.uint8)

# %%
imgNew.shape
# Out:
# (2472, 3072, 3)

# %%
plt.imshow(imgNew[:,:,::-1])
plt.show()

# %%
imgNew[:image.shape[0]][:]=image

# %%
plt.imshow(imgNew[:,:,::-1])
plt.show()

# %%
imgInverted=image[::-1,:,:]

# %%
plt.imshow(imgInverted[:,:,::-1])
plt.show()

# %%
imgNew[image.shape[0]:][:]=imgInverted

# %%
plt.imshow(imgNew[:,:,::-1])
plt.show()

# %%
cv2.imwrite('Watereffect.png',imgNew)
# Out:
# True
